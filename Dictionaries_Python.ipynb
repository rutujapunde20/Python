# %% [markdown]
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
# Dictionaries are written with curly brackets, and have keys and values:

# %% [markdown]
# ### Dictionary Items

# %% [markdown]
# Dictionary items are ordered, changeable, and does not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %% [markdown]
# ### Ordered or Unordered?

# %% [markdown]
# When we say that dictionaries are ordered, it means that the items have a defined order, and that order will not change.
#
# Unordered means that the items does not have a defined order, you cannot refer to an item by using an index.
#
# Dictionaries are changeable, meaning that we can change, add or remove items after the dictionary has been created.
#
# Dictionaries cannot have two items with the same key:

# %%
#create an empty dictionary
my_dictionary = {}

print(my_dictionary)

#to check the data type use the type() function
print(type(my_dictionary))

#output

#{}
#<class 'dict'>
# Out:
# {}
# <class 'dict'>

# %%
# Another way of creating an empty dictionary is to use the dict() function without passing any arguments.
# It acts as a constructor and creates an empty dictionary:

#create an empty dictionary
my_dictionary = dict()

print(my_dictionary)

#to check the data type use the type() function
print(type(my_dictionary))
# Out:
# {}
# <class 'dict'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dict_1 = {"Name": "John", "Age": 36, "Country": "Norway"}
print(dict_1)
# Out:
# {'Name': 'John', 'Age': 36, 'Country': 'Norway'}

# %%
thisdict = dict(name = "John", age = 36, country = "Norway")
print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %%
# Duplicate values will overwrite existing values:


thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
# Duplicate values will overwrite existing values:


thisdict = {"brand": "Ford", "brand": "Jaguar", "model": "Mustang", "year": 1964, "year": 2020}
print(thisdict)
print(len(thisdict))
# Out:
# {'brand': 'Jaguar', 'model': 'Mustang', 'year': 2020}
# 3

# %%
#Note brand and Brand - Case sensitive!


thisdict = {"brand": "Ford", "Brand": "Jaguar", "model": "Mustang", "year": 1964, "year": 2020}
print(thisdict)
# Out:
# {'brand': 'Ford', 'Brand': 'Jaguar', 'model': 'Mustang', 'year': 2020}

# %%
print(len(thisdict))
# Out:
# 4

# %% [markdown]
# Dictionary Items - Data Types

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grades = { "Math"        : 4,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7            
         }
print(grades)
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %%
grades["Math"]
# Out:
# 4

# %% [markdown]
# You can get the values for any of the keys using the square brackets notation. For example, you can get the Math grade as follows

# %%
print("Math grade is ", grades["Math"])
# Out:
# Math grade is  4

# %% [markdown]
# Unique keys

# %% [markdown]
# Naturally the key has to be unique. If the key is already present, it will update the value for that key

# %%
grades["Math"] = 3.9
grades
# Out:
# {'Math': 3.9, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %%
# If the key does not exist, it gets added
grades["Biology"] = 3.5
grades
# Out:
# {'Math': 3.9, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7, 'Biology': 3.5}

# %%
grades = { "Math"        : 4,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7}
 
print ( grades["Zoology"] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\1289393991.py in <module>
#       4            "English"     : 3.7}
#       5
# ----> 6 print ( grades["Zoology"] )
#
# KeyError: 'Zoology'

# %%
grades["Zoology"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\2645255333.py in <module>
# ----> 1 grades["Zoology"]
#
# KeyError: 'Zoology'

# %%
grades.get("Zoology")

# %%
b = grades.get("Zoology")
print(b)
# Out:
# None

# %%
grades.get("Math")
# Out:
# 4

# %%
grades["Math"]
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grades.get("zoology")

# %%
grades.get("English")  #case sensitive
# Out:
# 3.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
value = grades.get("Zoology") 
print ( value )
# Out:
# None

# %%
value = grades["Zoology"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10464\3973307448.py in <module>
# ----> 1 value = grades["Zoology"]
#
# KeyError: 'Zoology'

# %%
value = grades.get("English") 
print ( value )
# Out:
# 3.7

# %%
grades
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %%
grades['Biology'] =56

# %%
grades
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7, 'Biology': 56}

# %% [markdown]
# Vowels program

# %% [markdown]
# In this program, we will count the occurrence of each of the vowels.

# %% [markdown]
# For example, the sentence how are you has the following vowels
#
# o – 2
#
# e – 1
#
# u – 1
#
# a – 1
#
# – How to get initialize a dictionary
# – How to insert a key,value pair
# – How to check if a key exists

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sentence = input ( "Enter a sentence -")
 
vowels = ['a','e','i','o','u'] 
vowel_count = {}
 
for i in list(sentence) :
    if i in vowels :
        if vowel_count.get(i) == None :

                # key doesn't exist yet. add it
                vowel_count[i] = 1
                print(i)
                print(vowel_count)
        else :
                # key already exist. add to the value
                vowel_count[i] = vowel_count[i] + 1
                print(i)
                print(vowel_count)
print(vowel_count)
# Out:
# Enter a sentence -How are you
# o
# {'o': 1}
# a
# {'o': 1, 'a': 1}
# e
# {'o': 1, 'a': 1, 'e': 1}
# o
# {'o': 2, 'a': 1, 'e': 1}
# u
# {'o': 2, 'a': 1, 'e': 1, 'u': 1}
# {'o': 2, 'a': 1, 'e': 1, 'u': 1}

# %%
sentence = input ( "Enter a sentence -")
 
vowels = ['a','e','i','o','u'] 
vowel_count = {}
 
for i in list(sentence) :
    if i in vowels :
        if vowel_count.get(i) == None :
                # key doesn't exist yet. add it
                vowel_count[i] = 1
#                 print(i)
#                 print(vowel_count)
        else :
                # key already exist. add to the value
                vowel_count[i] = vowel_count[i] + 1
#                 print(i)
#                 print(vowel_count)
print(vowel_count)
# Out:
# Enter a sentence -How are you
# {'o': 2, 'a': 1, 'e': 1, 'u': 1}

# %% [markdown]
# The key is not ordered. Meaning, you cannot refer to values in a dictionary via an index. For example, this will given a key error.

# %%
grades[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10464\3757767530.py in <module>
# ----> 1 grades[0]
#
# KeyError: 0

# %%
grades = { "Math"        : 3.9,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7}

# %%
grades[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\3757767530.py in <module>
# ----> 1 grades[0]
#
# KeyError: 0

# %% [markdown]
# Iterate over the dictionary
#
# Since the keys are not ordered, there is no way you can use indexing to iterate dictionaries ( like you can do lists). However, Python provides simple for loop based iteration that provides keys in the dictionary. Inside the for loop, you can then access the value in the dictionary, based on the key.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in grades: 
    print(i)
# Out:
# Math
# Physics
# Chemistry
# English

# %%
for key in grades: 
    print(key)
# Out:
# Math
# Physics
# Chemistry
# English

# %%
grades["Math"]
# Out:
# 3.9

# %%
for something in grades: 
    print(grades[something])
# Out:
# 3.9
# 3.8
# 3.6
# 3.7

# %%
for key in grades: 
    print(grades[key])
# Out:
# 3.9
# 3.8
# 3.6
# 3.7

# %%
for key in grades: 
    print ( key , ":" , grades[key])
# Out:
# Math : 3.9
# Physics : 3.8
# Chemistry : 3.6
# English : 3.7

# %%
grades.items()
# Out:
# dict_items([('Math', 3.9), ('Physics', 3.8), ('Chemistry', 3.6), ('English', 3.7)])

# %%
b= grades.items()
print(b)
print(type(b))
print(type(grades))
# Out:
# dict_items([('Math', 3.9), ('Physics', 3.8), ('Chemistry', 3.6), ('English', 3.7)])
# <class 'dict_items'>
# <class 'dict'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for item in grades: 
    print(item)
# Out:
# Math
# Physics
# Chemistry
# English

# %%
for item in grades.items(): 
    print(item)
# Out:
# ('Math', 3.9)
# ('Physics', 3.8)
# ('Chemistry', 3.6)
# ('English', 3.7)

# %%
for item in grades.items() : 
    print (item[0])
# Out:
# Math
# Physics
# Chemistry
# English

# %%
for item in grades.items() : 
    print (item[1])
# Out:
# 3.9
# 3.8
# 3.6
# 3.7

# %%
for item in grades.items() : 
    print ( item[0] , " " , item[1])
# Out:
# Math   3.9
# Physics   3.8
# Chemistry   3.6
# English   3.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grades
# Out:
# {'Math': 3.9, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %% [markdown]
# ###### Key and Value Objects
# You can get keys and values as separate objects – not as lists, but as separate objects like we have seen before.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grades.keys()
# Out:
# dict_keys(['Math', 'Physics', 'Chemistry', 'English'])

# %%
keys = grades.keys()
print(keys)
print(type(keys))
# Out:
# dict_keys(['Math', 'Physics', 'Chemistry', 'English'])
# <class 'dict_keys'>

# %%
grades
# Out:
# {'Math': 3.9, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %% [markdown]
# This is not a List though – It is a dictionary view object. Think of it like a dynamic pointer to the dictionary keys. If the dictionary changes, this object changes as well.

# %%
grades["Biology"] = 3.6

# %%
grades
# Out:
# {'Math': 3.9, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7, 'Biology': 3.6}

# %%
keys
# Out:
# dict_keys(['Math', 'Physics', 'Chemistry', 'English', 'Biology'])

# %%
# If you instead wanted a static copy of the keys, you can convert it to a list


keys_list = list(keys)
keys_list
# Out:
# ['Math', 'Physics', 'Chemistry', 'English', 'Biology']

# %%
# dictionary of student id and grade in a particular subject
grades = { 103    : 4,
           101    : 3.8,
           102    : 3.6,
           104    : 3.7}
 
print ( sorted(grades.keys()) )
# Out:
# [101, 102, 103, 104]

# %%
grades
# Out:
# {103: 4, 101: 3.8, 102: 3.6, 104: 3.7}

# %% [markdown]
# ##### Values Object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
science_grades = { "Math"        : 4,
                   "Physics"     : 3.8,
                   "Chemistry"   : 3.6}

arts_grades =     { "English"     : 3.2,
                   "Art"         : 2.9,
                   "Drama"       : 3.0 }

# %%
science_grades.update(arts_grades)
print(science_grades)
print(arts_grades)
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.2, 'Art': 2.9, 'Drama': 3.0}
# {'English': 3.2, 'Art': 2.9, 'Drama': 3.0}

# %%
science_grades
arts_grades
# Out:
# {'English': 3.2, 'Art': 2.9, 'Drama': 3.0}

# %%
science_grades = { "Math"        : 4,
                   "Physics"     : 3.8,
                   "Chemistry"   : 3.6}
arts_grades =     {"Math"        : 3.9, 
                   "English"     : 3.2,
                   "Art"         : 2.9,
                   "Drama"       : 3.0 }
science_grades.update(arts_grades)

# %%
print(science_grades)
# Question : What is the value of the key “Math” after the code is executed ?
# Out:
# {'Math': 3.9, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.2, 'Art': 2.9, 'Drama': 3.0}

# %%
science_grades = { "Math"        : 4,
                   "Physics"     : 3.8,
                   "Chemistry"   : 3.6}
arts_grades =     {"Math"        : 3.9, 
                   "English"     : 3.2,
                   "Art"         : 2.9,
                   "Drama"       : 3.0 }
arts_grades.update(science_grades)
print(arts_grades)
# Out:
# {'Math': 4, 'English': 3.2, 'Art': 2.9, 'Drama': 3.0, 'Physics': 3.8, 'Chemistry': 3.6}

# %%
  grades = { "Math"      : 4,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grades
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %%
# Using the del keyword
del grades["Math"]
grades
# Out:
# {'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
    grades = { "Math"      : 4,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7}

# %%
grades.pop("Math")
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grades.clear()

# %%
grades
# Out:
# {}

# %% [markdown]
# ### Shallow copy
# Shallow copy of grades
#
# copy () function

# %%
grades = { "Math"        : 4,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7}

# %%
grades_c = grades.copy()

print(id(grades))
 
print(id(grades_c))
# Out:
# 2197475326528
# 2197475374336

# %%
grades["Biology"] = 3.5

# %%
print(grades)
 
print(grades_c)
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7, 'Biology': 3.5}
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %% [markdown]
# #### = ( equal to ) operator returns a new reference ( like a pointer ) to the same data.

# %%
grades_new = grades
id( grades_new )
# Out:
# 2197475326528

# %%
grades.clear()

# %%
grades_new
# Out:
# {}

# %%
    grades = { "Math"      : 4,
           "Physics"     : 3.8,
           "Chemistry"   : 3.6,
           "English"     : 3.7}
    grades.pop("Biology")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\2616783942.py in <module>
#       3        "Chemistry"   : 3.6,
#       4        "English"     : 3.7}
# ----> 5 grades.pop("Biology")
#
# KeyError: 'Biology'

# %%
del grades["Biology"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\879583824.py in <module>
# ----> 1 del grades["Biology"]
#
# KeyError: 'Biology'

# %%
grades
# Out:
# {'Math': 4, 'Physics': 3.8, 'Chemistry': 3.6, 'English': 3.7}

# %%
grades.popitem()
# Out:
# ('Math', 4)

# %%
grades
# Out:
# {}

# %% [markdown]
# - clear(): This method removes all the key-value pairs from a dictionary.
#
# - copy(): This method returns a shallow copy of the dictionary.
#
# - fromkeys(): This method creates a new dictionary with the specified keys and values. If the values are not provided, they default to None.
#
# - get(): This method returns the value associated with a given key in the dictionary. If the key is not found in the dictionary, it returns the default value (which is None by default).
#
# - items(): This method returns a list of tuples containing all the key-value pairs in the dictionary.
#
# - keys(): This method returns a list of all the keys in the dictionary.
#
# - pop(): This method removes and returns the value associated with the given key in the dictionary. If the key is not found in the dictionary, it raises a KeyError.
#
# - popitem(): This method removes and returns an arbitrary key-value pair from the dictionary. If the dictionary is empty, it raises a KeyError.
#
# - setdefault(): This method returns the value associated with a given key in the dictionary. If the key is not found in the dictionary, it adds the key to the dictionary with the specified default value (which is None by default) and returns that value.
#
# - update(): This method updates the dictionary with the key-value pairs from another dictionary or an iterable of key-value pairs.
#
# - values(): This method returns a list of all the values in the dictionary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
my_dict.clear()
print(my_dict) # Output: {}
# Out:
# {}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
new_dict = my_dict.copy()
print(new_dict) # Output: {'a': 1, 'b': 2, 'c': 3}
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
keys = ['a', 'b', 'c']
values = [1, 2, 3]
my_dict = dict.fromkeys(keys, values)
print(my_dict) # Output: {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': [1, 2, 3]}
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': [1, 2, 3]}

# %%
list_1 = ['a', 'b', 'c']  # as a key 
list_2 = [1, 2,3]   # as a value
dict_1 = dict.fromkeys(list_1, list_2)

print(dict_1)
print(type(dict_1))
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': [1, 2, 3]}
# <class 'dict'>

# %%
keys = ['a', 'b', 'c']
my_dict = dict.fromkeys(keys)
print(my_dict) 

# Values not provided and so value is taken as none
# Out:
# {'a': None, 'b': None, 'c': None}

# %%
# Create a dictionary with 3 keys, all with the value 0:

x = ('key1', 'key2', 'key3')
y = 0

thisdict = dict.fromkeys(x, y)

print(thisdict)
# Out:
# {'key1': 0, 'key2': 0, 'key3': 0}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value = my_dict.get('d', 0)
print(value)
# Out:
# 0

# %% [markdown]
# value = my_dict.get('d', 0): This line uses the get() method of dictionaries to retrieve the value associated with the key 'd'. The get() method takes two arguments: the key to be retrieved and a default value to be returned if the key is not found. In this case, the key 'd' is not present in my_dict, so the get() method returns the default value 0.

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value = my_dict.get('d', -1)
print(value)
# Out:
# -1

# %%
value = my_dict.get('e')
print(value)
# Out:
# None

# %%
value = my_dict.get('a')
print(value)
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
items = my_dict.items()
print(items) # Output: dict_items([('a', 1), ('b', 2), ('c', 3)])
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])

# %%
dict_1 = {1:1, 2:4, 3:9}

# %%
type(dict_1)
# Out:
# dict

# %%
dict_1.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
dict_1.items()
# Out:
# dict_items([(1, 1), (2, 4), (3, 9)])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
keys = my_dict.keys()
print(keys) # Output: dict_keys(['a', 'b', 'c'])
# Out:
# dict_keys(['a', 'b', 'c'])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value = my_dict.pop('b')
print(my_dict) # Output: {'a': 1, 'c': 3}
print(value) # Output: 2
# Out:
# {'a': 1, 'c': 3}
# 2

# %%
my_dict.pop('d')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10464\2487906886.py in <module>
# ----> 1 my_dict.pop('d')
#
# KeyError: 'd'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
item = my_dict.popitem()
print(my_dict) # Output: {'a': 1, 'b': 2}
print(item) # Output: ('c', 3)
# Out:
# {'a': 1, 'b': 2}
# ('c', 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
value = my_dict.setdefault('d', 0)
print(my_dict) # Output: {'a': 1, 'b': 2, 'c': 3, 'd': 0}
print(value) # Output: 0
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 0}
# 0

# %%
b=my_dict.get('e')
print(b)
# Out:
# None

# %% [markdown]
# ## Application of set default in dictionary
# As you can see, the split() method has split the string into a list of substrings based on the spaces between the words. The punctuation marks are included in the resulting substrings.

# %%
text = "Hello, world! How are you today?"
words = text.split()
print(words)
# Out:
# ['Hello,', 'world!', 'How', 'are', 'you', 'today?']

# %% [raw]
# The setdefault() method in Python dictionaries is a useful method for setting default values for keys that do not exist in the dictionary. The setdefault() method returns the value of the key if it exists in the dictionary, and if it does not exist, it sets the key with the default value provided, and returns that value.
#
# One real-world application of the setdefault() method is when you are working with a dictionary of counts. For example, you may want to count the number of times each word appears in a text document. You can use a dictionary to store the word counts, and the setdefault() method to set the default count for a word that has not yet been encountered.

# %%
text = "the quick brown fox jumped over the lazy dog"
word_counts = {}
for word in text.split():
    word_counts[word] = word_counts.setdefault(word, 0) + 1

print(word_counts)
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumped': 1, 'over': 1, 'lazy': 1, 'dog': 1}

# %% [raw]
# In this example, the text variable contains a string of words. The word_counts dictionary is initialized as an empty dictionary. The for loop iterates over each word in the text, and for each word, it sets the default count to 0 using the setdefault() method. It then increments the count for the word by 1. Finally, the word_counts dictionary is printed, which shows the count of each word in the text.
#
# The setdefault() method is useful in this example because it allows you to set the default count for each word to 0 without having to first check if the word is already in the dictionary. This makes the code simpler and more efficient.
#
# The setdefault() method is used to get the value of the word key from the word_counts dictionary. If the key does not exist, it is added to the dictionary with a default value of 0. The setdefault() method returns the value associated with the word key in the dictionary.
#
# The value of the word key in the word_counts dictionary is then incremented by 1, using the + 1 operator. The updated count for the word is then stored in the dictionary using the assignment operator (=).
#
# So, in summary, the code line word_counts[word] = word_counts.setdefault(word, 0) + 1 checks if the word key is already in the word_counts dictionary. If it is, it increments the count for the word by 1. If it is not, it adds the key to the dictionary with a count of 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Example 1: Updating a dictionary with a single key-value pair
my_dict = {'a': 1, 'b': 2, 'c': 3}
my_dict.update({'d': 4})
print(my_dict) # Output: {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Example 2: Updating a dictionary with multiple key-value pairs

my_dict = {'a': 1, 'b': 2, 'c': 3}
my_dict.update({'d': 4, 'e': 5})
print(my_dict) # Output: {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
# Example 3: Updating a dictionary with another dictionary

my_dict1 = {'a': 1, 'b': 2}
my_dict2 = {'b': 3, 'c': 4}
my_dict1.update(my_dict2)
print(my_dict1) # Output: {'a': 1, 'b': 3, 'c': 4}
# Out:
# {'a': 1, 'b': 3, 'c': 4}
