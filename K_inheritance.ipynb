# %% [markdown]
# Inheritance

# %% [markdown]
# https://www.toppr.com/guides/python-guide/tutorials/python-object-and-class/inheritance/python-inheritance-with-examples/
#
#
# https://www.scaler.com/topics/python/inheritance-in-python/
#
#
# https://pynative.com/python-inheritance/

# %% [markdown]
# The process of inheriting the properties of the parent class into a child class is called inheritance. The existing class is called a base class or parent class and the new class is called a subclass or child class or derived class.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Base class /parent class 
class Vehicle:
    def Vehicle_info(self):
        print('Inside Vehicle (parent) class')
# Child class
class Car(Vehicle):
    def car_info(self):
        print('Inside Car (child) class')
# Create object of Car/ child class 
car = Car()
# access Vehicle's info using car object
car.Vehicle_info()
car.car_info()
# Out:
# Inside Vehicle (parent) class
# Inside Car (child) class

# %%
h = Vehicle()

# %%
h.Vehicle_info

# %% [markdown]
# ### Multiple Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Parent class 1
class Person:
    def person_info(self, name, age):
        print('Inside Person class')
        print('Name:', name, 'Age:', age)
# Parent class 2
class Company:
    def company_info(self, company_name, location):
        print('Inside Company class')
        print('Name:', company_name, 'location:', location)
# Child class
class Employee(Person, Company):
    def Employee_info(self, salary, skill):
        print('Inside Employee class')
        print('Salary:', salary, 'Skill:', skill)

# Create object of Employee
emp = Employee()

# access data
emp.person_info('Jessa', 28)
emp.company_info('Google', 'Atlanta')
emp.Employee_info(12000, 'Machine Learning')
# Out:
# Inside Person class
# Name: Jessa Age: 28
# Inside Company class
# Name: Google location: Atlanta
# Inside Employee class
# Salary: 12000 Skill: Machine Learning

# %% [markdown]
# ### Multilevel inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Base class
class Vehicle:
    def Vehicle_info(self):
        print('Inside Vehicle class')

# Child class
class Car(Vehicle):
    def car_info(self):
        print('Inside Car class')
# Child class
class SportsCar(Car):
    def sports_car_info(self):
        print('Inside SportsCar class')

        
# Create object of SportsCar
spcar = SportsCar()

# access Vehicle's and Car info using SportsCar object
spcar.Vehicle_info()
spcar.car_info()
spcar.sports_car_info()
# Out:
# Inside Vehicle class
# Inside Car class
# Inside SportsCar class

# %% [markdown]
# In the above example, we can see there are three classes named Vehicle, Car, SportsCar. Vehicle is the superclass, Car is a child of Vehicle, SportsCar is a child of Car. So we can see the chaining of classes.

# %% [markdown]
# ### Hierarchical Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#  Let’s create ‘Vehicle’ as a parent class and two child class ‘Car’ and ‘Truck’ 
# as a parent class.

# %%
class Vehicle:
    def info(self):
        print("This is Vehicle")

class Car(Vehicle):
    def car_info(self, name):
        print("Car name is:", name)

class Truck(Vehicle):
    def truck_info(self, name):
        print("Truck name is:", name)

obj1 = Car()
obj1.info()
obj1.car_info('BMW')

obj2 = Truck()
obj2.info()
obj2.truck_info('Ford')
# Out:
# This is Vehicle
# Car name is: BMW
# This is Vehicle
# Truck name is: Ford

# %% [markdown]
# ### Hybrid Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Vehicle:
    def vehicle_info(self):
        print("Inside Vehicle class")
class Car(Vehicle):
    def car_info(self):
        print("Inside Car class")
class Truck(Vehicle):
    def truck_info(self):
        print("Inside Truck class")
# Sports Car can inherits properties of Vehicle and Car -- multiple
class SportsCar(Car, Vehicle):    #class Sportscar(Car) --multilevel
    def sports_car_info(self):
        print("Inside SportsCar class")
# create object
s_car = SportsCar()
s_car.vehicle_info()
s_car.car_info()
s_car.sports_car_info()
# Out:
# Inside Vehicle class
# Inside Car class
# Inside SportsCar class

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Python super() function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Company:
    def company_name(self):
        return 'Google'

class Employee(Company):
    def info(self):
        # Calling the superclass method using super()function
        c_name = super().company_name()
        print("Jessa works at", c_name)

# Creating object of child class
emp = Employee()
emp.info()
# Out:
# Jessa works at Google

# %%
class Company:
    def company_name(self):
        return 'Google'

class Employee(Company):
    def info(self):
        print('Hello')

# %%
e=Employee()

# %%
e.company_name()
# Out:
# 'Google'

# %%
class Company:
    def company_name(self):
        return 'Google'

class Employee(Company):
    def info(self):
        company_name=super().company_name()
       
        print("Jessa works at", company_name)

# Creating object of child class
emp = Employee()
# print(emp.company_name())
emp.info()
# Out:
# Jessa works at Google

# %%
class Emp():
	def __init__(self, idd, name, Add):
		self.idd = idd
		self.name = name
		self.Add = Add

# Class freelance inherits EMP
class Freelance(Emp):
	def __init__(self, idd, name, Add, Emails):
		super().__init__(idd, name, Add)
		self.Emails = Emails

Emp_1 = Freelance(103, "Suraj kr gupta", "Noida" , "KKK@gmails")
print('The ID is:', Emp_1.idd)
print('The Name is:', Emp_1.name)
print('The Address is:', Emp_1.Add)
print('The Emails is:', Emp_1.Emails)
# Out:
# The ID is: 103
# The Name is: Suraj kr gupta
# The Address is: Noida
# The Emails is: KKK@gmails

# %%
# super() function through hierarchical inheritance 
class Emp():
	def __init__(self, idd, name, Add):
		self.idd = idd
		self.name = name
		self.Add = Add

class nontechical_staff(Emp):
	def __init__(self, idd, name, Add, type_of_work):
		super().__init__(idd, name, Add)
		self.type_of_work = type_of_work
        
class techical_staff(Emp):
	def __init__(self, idd, name, Add, project_name):
		super().__init__(idd, name, Add)
		self.project_name= project_name

    
Emp_1 = nontechical_staff(103, "Suraj kr gupta", "Noida" , "sales")
print('The ID is:', Emp_1.idd)
print('The Name is:', Emp_1.name)
print('The Address is:', Emp_1.Add)
print('The type of work is:', Emp_1.type_of_work)

Emp_2 = techical_staff(201, "Rakesh S", "Mumbai" , "Machine Learning")
print('The ID is:', Emp_2.idd)
print('The Name is:', Emp_2.name)
print('The Address is:', Emp_2.Add)
print('The type of work is:', Emp_2.project_name)
# Out:
# The ID is: 103
# The Name is: Suraj kr gupta
# The Address is: Noida
# The type of work is: sales
# The ID is: 201
# The Name is: Rakesh S
# The Address is: Mumbai
# The type of work is: Machine Learning

# %%
class Company:
    def company_name(self):
        return 'Google'

class Employee(Company):
    def info(self):
        # Calling the superclass method using super()function
        anything = super().company_name()
        print("Jessa works at", anything)

# Creating object of child class
emp = Employee()
emp.info()
# Out:
# Jessa works at Google

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### issubclass()

# %% [markdown]
# In Python, we can verify whether a particular class is a subclass of another class. For this purpose, we can use Python built-in function issubclass(). This function returns True if the given class is the subclass of the specified class. Otherwise, it returns False.

# %% [markdown]
# https://pynative.com/python-inheritance/

# %%
class Company:
    def fun1(self):
        print("Inside parent class")

class Employee(Company):  
    def fun2(self):
        print("Inside child class.")

class Player:
    def fun3(self):
        print("Inside Player class.")

# Result True
print(issubclass(Employee, Company))

# Result False
print(issubclass(Employee, list))

# Result False
print(issubclass(Player, Company))

# Result True
print(issubclass(Employee, (list, Company)))

# Result True
print(issubclass(Company, (list, Company)))
# Out:
# True
# False
# False
# True
# True

# %%
print(issubclass(Company, Company))
print(issubclass(Employee, Employee))
print(issubclass(Company, Company))
print(issubclass(Player, list))
print(issubclass(Employee, (Company, Player)))
# Out:
# True
# True
# True
# False
# True

# %% [markdown]
# ### Method Overriding

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Shape:
    def draw(self):
        print("Drawing a generic shape")
class Square(Shape):
    def draw(self):
        print("Drawing a square")
class Rectangle(Shape):
    def draw(self):
        print("Drawing a rectangle")
class Circle(Shape):
    def draw(self):
        print("Drawing a circle")
# Create objects of the classes
shape = Shape()
square = Square()
rectangle = Rectangle()
circle = Circle()

square.draw()



# Call the draw() method on each object
shape.draw()         # Output: Drawing a generic shape
square.draw()        # Output: Drawing a square
rectangle.draw()     # Output: Drawing a rectangle
circle.draw()        # Output: Drawing a circle
# Out:
# Drawing a generic shape
# Drawing a square
# Drawing a rectangle
# Drawing a circle

# %%
# Method overriding
class Vehicle:
    def max_speed(self):
        print("max speed is 100 Km/Hour")
class Car(Vehicle):
    # overridden the implementation of Vehicle class
    def max_speed(self):
        print("max speed is 200 Km/Hour")
# Creating object of Car class
car = Car()
car.max_speed()
# Out:
# max speed is 200 Km/Hour

# %% [markdown]
# ### Method Resolution Order

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        print(" In class B")

class C(B, A):
    def process(self):
        print(" In class C")

# Creating object of C class
C1 = C()
C1.process()  
print(C.mro())
# Out:
#  In class C
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
print(A.mro())
print(B.mro())
# Out:
# [<class '__main__.A'>, <class 'object'>]
# [<class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        print(" In class B")

class C(B, A):
    pass
        
# Creating object of C class
C1 = C()
C1.process()
print(C.mro())
# Out:
#  In class B
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    pass

class C(B, A):
    pass
        
# Creating object of C class
C1 = C()
C1.process()
print(C.mro())
# Out:
#  In class A
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    pass

class C(B, A):
    pass
        
# Creating object of C class
C1 = C()
C1.process()
print(C.mro())
# Out:
#  In class A
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
class A:
    pass

class B(A):
    pass

class C(B, A):
    speed=
        
# Creating object of C class
C1 = C()
C1.process()
print(C.mro())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1108\2207697782.py in <module>
#      10 # Creating object of C class
#      11 C1 = C()
# ---> 12 C1.process()
#      13 print(C.mro())
#
# AttributeError: 'C' object has no attribute 'process'

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        pass
class C(B, A):
    def process(self):
        pass
# Creating object of C class
C1 = C()
C1.process()
print(C.mro())
# Out:
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python program showing
# how MRO works

class A:
	def rk(self):
		print(" In class A")
class B(A):
	def rk(self):
		print(" In class B")
class C(A):
	def rk(self):
		print("In class C")

# classes ordering
class D(B, C):
	pass
	
r = D()
r.rk()
# Out:
#  In class B

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python program showing
# how MRO works

class A:
	def rk(self):
		print(" In class A")
class B(A):
    pass
class C(A):
	def rk(self):
		print('From C')

# classes ordering
class D(B, C):
	pass
	
r = D()
r.rk()
# Out:
# From C

# %%
# Python program showing
# how MRO works

class A:
	def rk(self):
		print(" In class A")
class B(A):
    pass
class C(A):
    pass

# classes ordering
class D(B, C):
	pass
	
r = D()
r.rk()
# Out:
#  In class A

# %%
class A:
	def rk(self):
		print(" In class A")

class B(A):
	def rk1(self):
		pass

class C(A):
	def rk2(self):
		pass

class D(B, C):
	pass
	
r = D()
r.rk()  # Call rk() method on the r object
# Out:
#  In class A

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        print(" In class B")

class C(B, A):
        pass

# Creating object of C class
C1 = C()
C1.process()
# Out:
#  In class B

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    pass

class C(B, A):
        pass

# Creating object of C class
C1 = C()
C1.process()
# Out:
#  In class A

# %%
class A:
    def method(self):
        print("A.method() called")

class B:
    pass

class C(B, A):
    pass

c = C()
c.method()
# Out:
# A.method() called

# %%
class A:
    def method(self):
        print("A.method() called")

class B:
    def method(self):
        print("B.method() called")

class C(A, B):
    pass

class D(C, B):
    pass

d = D()
d.method()
# Out:
# A.method() called

# %%
class A:
    def method(self):
        print("A.method() called")

class B:
    def method(self):
        print("B.method() called")

class C(B, A):
    pass

class D(C, B):
    pass

d = D()
d.method()
# Out:
# B.method() called

# %% [markdown]
# References
#
# http://www.srikanthtechnologies.com/blog/python/mro.aspx
#
#
# https://pynative.com/python-inheritance/

# %%
# Python program showing
# how MRO works

class A:
    def rk(self):
        print("In class A")
	
class B(A):
	pass
class C(A):
	def rk(self):
		print("In class C")

# classes ordering
class D(B, C):
	pass
	
r = D()
r.rk()
# Out:
# In class C

# %%
class A:
    def process(self):
        print("In class A")

class B(A):
    pass

class C(B, A):
    pass

# Creating object of C class
C1 = C()
C1.process()

# Using isinstance() to check object type
if isinstance(C1, object):
    print("C1 is an object")
else:
    print("C1 is not an object")

# Using dir() to inspect object attributes
print("Attributes of C1:")
print(dir(C1))

# Using __class__ attribute to get object's class
print("C1's class is:", C1.__class__)
# Out:
# In class A
# C1 is an object
# Attributes of C1:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'process']
# C1's class is: <class '__main__.C'>

# %% [raw]
# In this modified code, we create an object C1 of the C class, and call its process() method. We then demonstrate some uses of the object class:
#
# We use the isinstance() function to check if C1 is an instance of the object class. Since all classes in Python inherit from object by default, this will always be true. The output will be "C1 is an object".
#
# We use the dir() function to inspect the attributes of the C1 object. This will show us a list of all the attributes and methods of the object, including those inherited from the object class. The output will be a long list of attribute names.
#
# We use the __class__ attribute of the C1 object to get its class. This will return the C class, since that is the class of the object. The output will be "C1's class is: <class 'main.C'>".
