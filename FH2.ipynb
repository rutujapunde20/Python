# %%
#Writing in a file
#Open will create a new file , if file is not create already 

with open("November.txt","w")as f:
    f.write("This is Dummy file")

# %%
with open("Augustt.txt","x") as f:
    f.write("This is content file")

# %%
with open("Augustt.txt","r") as f:
    content=f.read()
    print(content)
# Out:
# This is content file

# %%
with open('sample9.txt') as f:
    content=f.read()
    print(f.closed)
print(f.closed)
# Out:
# False
# True

# %%
with open('sample9.txt') as f:
    content=f.read()
    print(f.closed)
print(f.closed)
c1=f.read()
# Out:
# False
# True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       3     print(f.closed)
#       4 print(f.closed)
# ----> 5 c1=f.read()
#
# ValueError: I/O operation on closed file.

# %%
with open('sample9.txt') as f:
    content=f.read()
    print(f.closed)
print(f.closed)
print(content)
# Out:
# False
# True
# Line 1
# Seven
# Mentor
# This is Line 4
# Line 5

# %%
with open('sample9.txt') as f:
    content=f.read()
    print(f.closed) #False
 
print(f.closed) #True
print(f.mode)
print(f.name)
print(content)
print(len(content))
# Out:
# False
# True
# r
# sample9.txt
# Line 1
# Seven
# Mentor
# This is Line 4
# Line 5
# 41

# %%
with open("capital_city.txt","r") as f1:
    for line in f1:
        if line.startswith("Answer") is True:

            with open("Answer.txt","a") as f2:
                f2.write(line)

# %%
with open("capital_city.txt","r") as f1:
    for line in f1:
        if ("Answer" in line):

            with open("Answer100.txt","a") as f2:
                f2.write(line)

# %%
with open ("Augustt.txt","r") as f:
    #read the contents of the file
    text=f.read()
    print(type(text)) 

    #split the text into words
    words=text.split()
    print(type(words))

   #print the number of words
    print("Number of words i the file:",len(words))
# Out:
# <class 'str'>
# <class 'list'>
# Number of words i the file: 4

# %%
#WAPP that reads a text file and prints the  numbers of words in the text file 

with open("Sample22.txt","r") as file:
    text=file.read()
    words=text.split()
    print(words)
    print("Number of words in the file:",len(words))
# Out:
# ['Line', '1', 'Line', '2']
# Number of words in the file: 4

# %%
#WAPP that reads a text file and prints the  numbers of lines in the text file 

with open ("Sample22.txt","r") as f:
    lines=f.readlines()
    print(type(lines))

    print("Number of lines in the file",len(lines))
# Out:
# <class 'list'>
# Number of lines in the file 2

# %%
with open("forsample.txt","r") as f:
    text=f.read()
    new_text=text.replace("testing","analysis")
    with open ("fs.txt","w") as f2:
        f2.write(new_text)

# %%
with open("Flower.png","rb") as file:
    content=file.read() #reading all files
    print(content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe2\x02@ICC_PROFILE\x00\x01\x01\x00\x00\x020ADBE\x02\x10\x00\x00mntrRGB XYZ \x07\xd0\x00\x08\x00\x0b\x00\x13\x003\x00;acspAPPL\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-ADBE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ncprt\x00\x00\x00\xfc\x00\x00\x002desc\x00\x00\x010\x00\x00\x00kwtpt\x00\x00\x01\x9c\x00\x00\x00\x14bkpt\x00\x00\x01\xb0\x00\x00\x00\x14rTRC\x00\x00\x01\xc4\x00\x00\x00\x0egTRC\x00\x00\x01\xd4\x00\x00\x00\x0ebTRC\x00\x00\x01\xe4\x00\x00\x00\x0erXYZ\x00\x00\x01\xf4\x00\x00\x00\x14gXYZ\x00\x00\x02\x08\x00\x00\x00\x14bXYZ\x00\x00\x02\x1c\x00\x00\x00\x14text\x00\x00\x00\x00Copyright 2000 Adobe Systems Incorporated\x00\x00\x00desc\x00\x00\x00\x00\x00\x00\x00\x11Adobe RGB (1998)\x00
# ...

# %%
pwd     #print working directory
# Out:
# 'd:\\Workspace\\FH'
